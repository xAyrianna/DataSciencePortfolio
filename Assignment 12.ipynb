# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('archive GOT/character-deaths.csv')

# %%
data.head()
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)             None       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
# 3            Adrack Humble    House Greyjoy       300.0            5.0
# 4           Aemon Costayne        Lannister         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
# 3           20.0                20.0       1         1    0    0    0    0
# 4            NaN                 NaN       1         1    0    0    1    0
#
#    DwD
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0

# %%
data.groupby('Allegiances').mean()
# Out:
#                  Death Year  Book of Death  Death Chapter  Book Intro Chapter  \
# Allegiances
# Arryn            299.333333       2.666667      47.666667           35.086957
# Baratheon        299.200000       2.750000      38.166667           20.851852
# Greyjoy          299.250000       3.375000      39.000000           18.862745
# House Arryn      299.000000       2.000000      29.000000           29.428571
# House Baratheon  299.000000       2.600000      38.000000           11.000000
# House Greyjoy    299.214286       2.571429      52.785714           34.916667
# House Lannister  299.166667       2.769231      40.545455           26.000000
# House Martell    300.000000       3.000000      70.000000           14.333333
# House Stark      298.578947       1.842105      47.631579           20.200000
# House Targaryen  299.250000       3.250000      32.000000           22.222222
# House Tully      299.000000       2.600000      30.600000           34.625000
# ...

# %%
sns.barplot(y="Book of Death", x="Allegiances", data=data)
# Out:
# <AxesSubplot:xlabel='Allegiances', ylabel='Book of Death'>

# %%
sns.barplot(y="Death Chapter", x="Allegiances", data=data)
# Out:
# <AxesSubplot:xlabel='Allegiances', ylabel='Death Chapter'>

# %%
sns.barplot(y="Death Year", x="Allegiances", data=data)
# Out:
# <AxesSubplot:xlabel='Allegiances', ylabel='Death Year'>

# %%
sns.barplot(y="Book Intro Chapter", x="Allegiances", data=data)
# Out:
# <AxesSubplot:xlabel='Allegiances', ylabel='Book Intro Chapter'>
